# %%
a="Ranganath"
b="Bangalore"
c="ranganaths0505@gmail.com"
print(a)
print(b)
print(c)
# Out:
# Ranganath
# Bangalore
# ranganaths0505@gmail.com

# %%
print('Need to learn "github" usage')
# Out:
# Need to learn "github" usage

# %%
a=38
b=98
c=13
print(a+b+c)
# Out:
# 149

# %%
print('''i need
to do the
assignments this weekend''')
# Out:
# i need
# to do the
# assignments this weekend

# %%
print("Prthvi")
print("Dhrauv")
print("Singham")
print("Agni")
print("Ashok")
# Out:
# Prthvi
# Dhrauv
# Singham
# Agni
# Ashok

# %%
print(1, end="\t")
print(2, end="\t")
print(3, end="\t")
print(4, end="\t")
print(5)
# Out:
# 1	2	3	4	5

# %%
print("Bangalore", end="|")
print("Chennai", end="|")
print("Pune", end="|")
print("Delhi", end="|")
print("Kolkata", end="|")
# Out:
# Bangalore|Chennai|Pune|Delhi|Kolkata|

# %%
print("My", end=' ')
print("name", end=' ')
print("is", end=' ')
print("ranganath", end=' ')
print("s", end=' ')
# Out:
# My name is ranganath s

# %%
print(''' My name is Ranganath, i am
currently working in
DXC Technology company leading at team
of 5 members handling SR''')
# Out:
#  My name is Ranganath, i am
# currently working in
# DXC Technology company leading at team
# of 5 members handling SR

# %%
# print("I have joined a Cousre in Edukron")
print("To learn data science and AI.")
# Out:
# To learn data science and AI.

# %%
print("This line is at the top level and will work fine.")

    print("This line will cause an IndentationError.")
# Out:
#   File "/tmp/ipykernel_606/1134095638.py", line 3
#     print("This line will cause an IndentationError.")
#     ^
# IndentationError: unexpected indent

# %%
print(f"5 + 5 = {5 + 5}")
# Out:
# 5 + 5 = 10
