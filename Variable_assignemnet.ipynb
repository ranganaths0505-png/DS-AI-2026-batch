# %%
#Create a variable 'student_name' and assign your name to it. Print it.

student_name="Ranganath"
print(student_name)
# Out:
# Ranganath

# %%
#Create a variable 'course_name' and assign 'Python Data Science' to it. Print it.
course_name="Python Data Science"
print(course_name)
# Out:
# Python Data Science

# %%
#Create a variable 'discount' and assign 150 to it. Calculate and print 'final_fee'.
Discount=150
final_fee=Discount
print(final_fee)
# Out:
# 150

# %%
#Write code to assign the value 100 to three variables x, y, and z at once.
x=y=z=100

# %%
Data=50
data=100
print(Data)
print(data)
# Out:
# 50
# 100

# %%
#Create variables for storing your home address: house_no, street, city, pincode. Print them in a single line.
house_no=202
street=5
city="Bangalore"
pincode=560040
print(f"{house_no},{street},{city},{pincode}")
# Out:
# 202,5,Bangalore,560040

# %%
#Assign your age to variable 'my_age'. Add 5 to it and update the same variable. Print the updated value.
my_age=32
my_age+=5
print(my_age)
# Out:
# 37
